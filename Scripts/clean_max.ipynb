# %% [markdown]
# # Cleaning Max's Data Set
# Data columns are analyzed sequentially for missing values and typos. Missing values or otherwise unusable data is dropped. Cleaning effects are cumulative. Drop counts are recorded and an overall drop rate is presented at the end. Typos are fixed by inspection whenever possible.
#
# The key takeaways are that missing receipt values generates a large amount of unusable data and that multiple assigned participants are missing from the data set.

# %%
import re
import datetime

import pandas as pd

# %%
# %%time
DATA_PATH = '../Data/'
FILE_NAME = 'Max, Samantha, Maria data.xlsx'
SHEET = 'Max'

df = pd.read_excel(DATA_PATH + FILE_NAME, sheet_name=SHEET)
initial_row_count = df.shape[0]
# Out:
# Wall time: 1.06 s

# %% [markdown]
# First, column names are standardized with other data sets to provide consistency and readability.

# %%
column_names = ['ID', 'Session', 'Receipt', 'Date', 
                'Item', 'Item2', 'Uncertain', 'Unknown', 
                'Quantity', 'Hit', 'Miss', 'Category', 'Comment']
df.columns = column_names
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2159 entries, 0 to 2158
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         2159 non-null   int64
#  1   Session    2159 non-null   int64
#  2   Receipt    1555 non-null   float64
#  3   Date       1718 non-null   datetime64[ns]
#  4   Item       2159 non-null   object
#  5   Item2      38 non-null     object
#  6   Uncertain  37 non-null     object
#  7   Unknown    87 non-null     object
#  8   Quantity   274 non-null    float64
#  9   Hit        0 non-null      float64
#  10  Miss       0 non-null      float64
#  11  Category   2059 non-null   object
#  12  Comment    494 non-null    object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 219.4+ KB

# %% [markdown]
# ### ID Column
# Participant identification numbers. Max was assigned particpants identified by 129, 136, 144, 147, 151, 156, 160, 112, 117, and 120. Additionally, all three transcribers were assigned the collection 121, 114, 137, 153, 141, 127, 130, 135, 148, and 158, to control for errors.

# %%
df.ID = df.ID.astype('uint8') # memory saving conversion

pids_assigned = ({129, 136, 144, 147, 151, 156, 160, 112, 117, 120} | 
                 {121, 114, 137, 153, 141, 127, 130, 135, 148, 158})

print(set(df.ID.unique()) ^ pids_assigned)
# Out:
# {147, 148, 151, 156, 158, 160, 112, 117, 120}

# %% [markdown]
# Multiple participants are missing.

# %% [markdown]
# ### Session Column
# A record of when the transcription was preformed. Transcription was divided into 6 sessions.

# %%
df.Session = df.Session.astype('uint8') # memory saving conversion

valid_sessions = [1, 2, 3, 4, 5, 6]

assert df.Session.isin(valid_sessions).all()

# %% [markdown]
# ### Receipt Column
# Enumeration of grocery receipts per session. df.info() has shown the existence of missing values, which must be dropped as distinguishing between different receipts is essential to this data set.

# %%
null_receipt_count = df.Receipt.isna().sum()
print(f'{null_receipt_count} rows missing Receipt values.')
df = df[df.Receipt.notna()]
df.Receipt = df.Receipt.astype('uint8')
# Out:
# 604 rows missing Receipt values.

# %% [markdown]
# This is a very large discard of data. Attributing additional receipt values would greatly increase the quantity of usable data. Next, discontinuities in the enumeration are examined as further validation.

# %%
print('(ID, Session): [Receipts]')
for pid in df.ID.unique():
    for session in df.loc[df.ID == pid, 'Session'].unique():
        receipt_numbers = list(df.loc[(df.ID == pid) & (df.Session == session), 'Receipt'].unique())
        if receipt_numbers != list(range(1, len(receipt_numbers) + 1)):
            print(f'({pid}, {session}):', receipt_numbers)
# Out:
# (ID, Session): [Receipts]
# (136, 1): [1, 2, 4, 5, 6, 7]

# %% [markdown]
# The tuple (136, 1, 3) is an empty receipt and is correctly absent from the data set.

# %% [markdown]
# ### Date Column
# Records purchase date on receipt if available. The approximate date range for data collection is 5/1/2020 to 12/31/2020.

# %%
# conversion hack to datetime while discarding time component
df.Date = pd.to_datetime(df.Date, errors='coerce').dt.date.astype('datetime64')

assert df.Date.dropna().between(datetime.datetime(2020, 5, 1), datetime.datetime(2020, 12, 31)).all()

# %% [markdown]
# ### Item Column
# Item descriptions are essential data and unidentifiable items are unusable. Item descriptions are also stripped of punctuation, whitespace, and formatting.

# %%
df.Item = df.Item.str.lower().str.strip().astype('string')
df.Item.value_counts(dropna=False).head()
# Out:
# bananas        43
# unknown        30
# blueberries    18
# eggs           16
# milk (2%)      14
# Name: Item, dtype: Int64

# %%
NULL_ITEM_DESC = r'unknown|n/a|missing'
null_item_count = df.Item.str.contains(NULL_ITEM_DESC).sum() + df.Item.isna().sum()
print('Additional items containing null-like language:')
display(df[df.Item.str.contains(NULL_ITEM_DESC)])

df = df[df.Item.notna()]
df = df[~df.Item.str.contains(NULL_ITEM_DESC)]
print(f'{null_item_count} null item descriptions.')
# Out:
# Additional items containing null-like language:
#        ID  Session  Receipt       Date         Item Item2 Uncertain Unknown  \
# 17    129        2        1 2020-06-30      unknown   NaN       NaN       x
# 60    129        3        2 2020-07-28      unknown   NaN       NaN       x
# 196   129        5        1 2020-08-18      unknown   NaN       NaN       x
# 259   136        2        1 2020-08-14      unknown   NaN       NaN       x
# 269   136        2        1 2020-08-14      unknown   NaN       NaN       x
# 270   136        2        1 2020-08-14      unknown   NaN       NaN       x
# 271   136        2        1 2020-08-14      unknown   NaN       NaN       x
# 272   136        2        1 2020-08-14      unknown   NaN       NaN       x
# 369   136        4        8 2020-09-10      unknown   NaN       NaN       x
# 894   137        1        1 2020-07-29      unknown   NaN       NaN       x
# 897   137        1        1 2020-07-29      unknown   NaN       NaN       x
# 916   137        1        2 2020-07-24      unknown   NaN       NaN       x
# 917   137        1        2 2020-07-24      unknown   NaN       NaN       x
# 983   137        4        2 2020-09-07      unknown   NaN       NaN       x
# 1130  153        2        3 2020-08-29      unknown   NaN       NaN     NaN
# 1131  153        2        3 2020-08-29      unknown   NaN       NaN     NaN
# 1310  141        5        1 2020-09-28      unknown   NaN       NaN       x
# 1311  141        5        1 2020-09-28      unknown   NaN       NaN       x
# 1312  141        5        1 2020-09-28      unknown   NaN       NaN       x
# 1319  141        5        1 2020-09-28      unknown   NaN       NaN       x
# 1329  141        5        1 2020-09-28      unknown   NaN       NaN       x
# 1334  141        5        1 2020-09-28      unknown   NaN       NaN       x
# 1336  141        5        1 2020-09-28      unknown   NaN       NaN       x
# 1368  127        1        1 2020-07-01      unknown   NaN       NaN       x
# 1385  127        1        2 2020-06-27      unknown   NaN       NaN       x
# 1418  127        2        2 2020-07-26      unknown   NaN       NaN       x
# 1751  130        5        2 2020-09-15      unknown   NaN       NaN       x
# 1836  135        1        4        NaT      unknown   NaN       NaN       x
# 1883  135        2        6        NaT      unknown   NaN       NaN       x
# 1896  135        2        8 2020-08-14      unknown   NaN       NaN       x
# 1900  135        2        9        NaT  all unknown   NaN       NaN       x
#
#       Quantity  Hit  Miss Category  \
# 17         2.0  NaN   NaN      NaN
# 60         NaN  NaN   NaN      NaN
# 196        NaN  NaN   NaN      NaN
# 259        NaN  NaN   NaN      NaN
# 269        NaN  NaN   NaN      NaN
# 270        NaN  NaN   NaN      NaN
# 271        NaN  NaN   NaN      NaN
# 272        NaN  NaN   NaN      NaN
# 369        2.0  NaN   NaN      NaN
# 894        NaN  NaN   NaN      NaN
# 897        NaN  NaN   NaN      NaN
# 916        NaN  NaN   NaN      NaN
# 917        NaN  NaN   NaN      NaN
# 983        2.0  NaN   NaN      NaN
# 1130       NaN  NaN   NaN      NaN
# 1131       NaN  NaN   NaN      NaN
# 1310       NaN  NaN   NaN      NaN
# 1311       2.0  NaN   NaN      NaN
# 1312       NaN  NaN   NaN      NaN
# 1319       NaN  NaN   NaN      NaN
# 1329       NaN  NaN   NaN      NaN
# 1334       2.0  NaN   NaN      NaN
# 1336       2.0  NaN   NaN      NaN
# 1368       NaN  NaN   NaN      NaN
# 1385       NaN  NaN   NaN      NaN
# 1418       NaN  NaN   NaN      NaN
# 1751       NaN  NaN   NaN      NaN
# 1836       NaN  NaN   NaN      NaN
# 1883       2.0  NaN   NaN      NaN
# 1896       NaN  NaN   NaN      NaN
# 1900       NaN  NaN   NaN      NaN
#
#                                                 Comment
# 17                        unknown: "100 Cal Trop/Mixed"
# 60                              unknown: "GV SF PW SYR"
# 196          unknown: "GV 100 WWWP;" Great Value _____?
# 259         unknown: "NGVC 2020 Anniv;" "0084932700262"
# 269         unknown: "DC $3.45 Natura;" "0084932700217"
# 270         unknown: "DC $3.45 Natura;" "0084932700217"
# 271         unknown: "DC $3.49 Lightl;" "0004345410080"
# 272         unknown: "DC Free Natural;" "0084932700134"
# 369   unknown: "STO CARTS RN" Simple Truth Organic _...
# 894                               unknown: "OTBCTC24OZ"
# 897                             unknown: "LICENSED RDR"
# 916                             unknown: "GE 10 CLRW D"
# 917                             unknown: "GV NAT SR CM"
# 983                           unknown: "TH ORIGINAL EM"
# 1130           light blocks the words; too hard to read
# 1131           light blocks the words; too hard to read
# 1310               unknown: "DV WHL STRAW" hard to read
# 1311                             unknown: "BESF VM MAS"
# 1312          unknown: "BESF VM CAU" Cauliflower maybe?
# 1319                   unknown: too hard to read at all
# 1329      unknown: "DFW CLIN 1.7" potentially deodorant
# 1334                            unknown: "EQ FEXD 15CT"
# 1336                                   unknown: "NNE 7"
# 1368                               unknown: "CUKE BRPL"
# 1385        unknown: "LTLE LF GRN 8Z" Lightlife Lowfat?
# 1418                  unknown: ""DIAMOND H.D. ASSOSTED"
# 1751        unknown: "KLX FAM SZ FAC TIS" Family sized?
# 1836                            unknown: "TR CN SMTH28"
# 1883              unknown: "TOTAL ADV TP" Toilet paper?
# 1896                                   unknown: "TETRO"
# 1900                       entire receipt is unreadable
# 31 null item descriptions.

# %% [markdown]
# Item descriptions are optionally formated as "item (modifier)", where modifier usually denotes an adjective like flavor, such as "ice cream (chocolate)". The reformat_modifier function removes this formatting by moving 'modifier' to beginning of text and droping the parentheses.

# %%
paren = re.compile(r'\(.+\)')

def reformat_modifier(text):
    m = paren.search(text)
    if m:
        text = ' '.join([m.group(0)[1:-1], text])
        text = paren.sub('', text)
    return text

# %%
df.Item = (df.Item
           .apply(reformat_modifier)
           .str.replace(r'[/(),"&]', ' ', regex=True)
           .str.replace(r'?', '', regex=False)
           .str.replace(r"'s", '', regex=False)
           .str.replace(r"coupon", '', regex=False)
           .str.strip())

# %% [markdown]
# ### Item2 Column
# Provides additional description of the grocery, but is too sparse to be useful.

# %%
df = df.drop(columns='Item2')

# %% [markdown]
# ### Uncertain Column
# Denotes low confidence in transcription.

# %%
display(df[df.Uncertain.notna()])
# Out:
#        ID  Session  Receipt       Date                   Item Uncertain  \
# 26    129        2        1 2020-07-02         sandwich rolls         x
# 70    129        3        2 2020-07-28            herb butter         x
# 151   129        4        2 2020-08-04            frozen meal         x
# 152   129        4        2 2020-08-04            frozen meal         x
# 176   129        5        1 2020-08-17         sandwich rolls         x
# 343   136        4        4 2020-09-04              baby food         x
# 357   136        4        6 2020-09-06                  bacon         x
# 362   136        4        7 2020-09-10              red sugar         x
# 376   136        4        8 2020-09-10              red sugar         x
# 435   136        5        5        NaT                   beef         x
# 449   136        5        6        NaT                   beef         x
# 864   114        6        1 2020-08-13       allergy medicine         x
# 895   137        1        1 2020-07-29         cleaning wipes         x
# 896   137        1        1 2020-07-29         cleaning spray         x
# 973   137        4        1 2020-09-14         crescent rolls         x
# 1331  141        5        1 2020-09-28         copper product         x
# 1335  141        5        1 2020-09-28                   zinc         x
# 1427  127        2        3 2020-07-28      12 pack softdrink         x
# 2108  144        1        5 2020-07-25  pizza seasoning blend         x
# 2148  144        1        6 2020-07-25  pizza seasoning blend         x
#
#      Unknown  Quantity  Hit  Miss    Category  \
# 26       NaN       NaN  NaN   NaN       Grain
# 70       NaN       NaN  NaN   NaN         NaN
# 151      NaN       NaN  NaN   NaN        Dish
# 152      NaN       NaN  NaN   NaN        Dish
# 176      NaN       NaN  NaN   NaN       Grain
# 343      NaN       NaN  NaN   NaN        Dish
# 357      NaN       NaN  NaN   NaN        Meat
# 362      NaN       NaN  NaN   NaN   Seasoning
# 376      NaN       NaN  NaN   NaN   Seasoning
# 435      NaN       NaN  NaN   NaN        Meat
# 449      NaN       NaN  NaN   NaN        Meat
# 864      NaN       NaN  NaN   NaN         NaN
# 895      NaN       NaN  NaN   NaN         NaN
# 896      NaN       NaN  NaN   NaN         NaN
# 973      NaN       3.0  NaN   NaN       Grain
# 1331     NaN       NaN  NaN   NaN         NaN
# 1335     NaN       NaN  NaN   NaN  Supplement
# 1427     NaN       NaN  NaN   NaN       Drink
# 2108     NaN       NaN  NaN   NaN   Seasoning
# 2148     NaN       NaN  NaN   NaN   Seasoning
#
#                                                 Comment
# 26                         uncertain: "KK SNDWCH RL 15"
# 70                            uncertain: "BUTR HERB SL"
# 151             uncertain: "LFC BOWL 11z;" Life Cuisine
# 152         uncertain: "LFC BOWL 10.875z;" Life Cuisine
# 176                        uncertain: "KK SNDWCH RL 15"
# 343   uncertain: "CMFRTS BABY" could be diapers, wip...
# 357   uncertain: "PC HMPL BACON" assumed Hempler's B...
# 362                         uncertain: "PC STO RED SUG"
# 376      uncertain: "PC STO RED SUG" & Duplicate of 4-7
# 435                              uncertain: "HTGF BEEF"
# 449            Duplicate of 5-5; uncertain: "HTGF BEEF"
# 864               uncertain: "UP 24HRALGY" Hard to read
# 895                             uncertain: "WIPE CLEAN"
# 896                           uncertain: "WIPE-CLEAN S"
# 973                                                 NaN
# 1331                          uncertain: "COPPER SCOUN"
# 1335  uncertain: "ZV ZINC;" category suggestion: "Su...
# 1427  uncertain: "DEP SFTDK 12PK FS" Soft drink most...
# 2108                     uncertain: "PEP'S PIZZA 30 OZ"
# 2148   uncertain: "PEP'S PIZZA 30 OZ;" Duplicate of 1-5

# %% [markdown]
# The transcription quality seems acceptable so the data will be kept.

# %%
df = df.drop(columns='Uncertain')

# %% [markdown]
# ### Unknown Column
# Denotes very low confidence in transcription.

# %%
display(df[df.Unknown.notna()])
# Out:
#       ID  Session  Receipt       Date                  Item Unknown  Quantity  \
# 6    129        1        1 2020-06-19           indian meal       x       2.0
# 25   129        2        1 2020-07-02        bake shop item       x       2.0
# 29   129        2        1 2020-07-02             deli item       x       NaN
# 39   129        2        1 2020-07-02          produce item       x       2.0
# 44   129        3        1 2020-07-31            dairy item       x       NaN
# 48   129        3        1 2020-07-31             deli item       x       NaN
# 52   129        3        1 2020-07-31          produce item       x       NaN
# 62   129        3        2 2020-07-28    buttermilk product       x       NaN
# 65   129        3        2 2020-07-28   lemon snack product       x       NaN
# 118  129        4        1 2020-08-11        bake shop item       x       NaN
# 121  129        4        1 2020-08-11             deli item       x       NaN
# 123  129        4        1 2020-08-11          produce item       x       NaN
# 124  129        4        1 2020-08-11          produce item       x       NaN
# 126  129        4        1 2020-08-11          produce item       x       NaN
# 141  129        4        2 2020-08-04        bake shop item       x       NaN
# 143  129        4        2 2020-08-04             deli item       x       NaN
# 158  129        4        2 2020-08-04          produce item       x       NaN
# 159  129        4        2 2020-08-04          produce item       x       NaN
# 160  129        4        2 2020-08-04          produce item       x       NaN
# 161  129        4        2 2020-08-04          produce item       x       NaN
# 179  129        5        1 2020-08-17             deli item       x       NaN
# 180  129        5        1 2020-08-17             deli item       x       NaN
# 186  129        5        1 2020-08-17          produce item       x       NaN
# 432  136        5        5        NaT  simple truth product       x       NaN
# 446  136        5        6        NaT  simple truth product       x       NaN
# 467  136        5        7        NaT  simple truth product       x       NaN
#
#      Hit  Miss Category                                          Comment
# 6    NaN   NaN      NaN                           unknown: "MEAL INDIAN"
# 25   NaN   NaN    Grain                      unknown: "REDUCE BAKE SHOP"
# 29   NaN   NaN      NaN                        unknown: "LOL AM WHT END"
# 39   NaN   NaN      NaN                       unknown: "REDUCED PRODUCE"
# 44   NaN   NaN    Dairy                       unknown: "GB WHT PCH 5.3Z"
# 48   NaN   NaN      NaN                               unknown: "DELI MI"
# 52   NaN   NaN      NaN                       unknown: "REDUCED PRODUCE"
# 62   NaN   NaN      NaN                             unknown: "BUTTERMIL"
# 65   NaN   NaN    Snack                           unknown: "LEMON SNACK"
# 118  NaN   NaN      NaN                      unknown: "REDUCE BAKE SHOP"
# 121  NaN   NaN      NaN                        unknown: "LOL AM WHT END"
# 123  NaN   NaN      NaN                            unknown: "PRODUCE MI"
# 124  NaN   NaN      NaN                       unknown: "REDUCED PRODUCE"
# 126  NaN   NaN      NaN                       unknown: "REDUCED PRODUCE"
# 141  NaN   NaN      NaN                      unknown: "REDUCE BAKE SHOP"
# 143  NaN   NaN      NaN                        unknown: "LOL AM WHT END"
# 158  NaN   NaN      NaN                      unknown: "GUARNTEE VAL 5LB"
# 159  NaN   NaN      NaN                       unknown: "REDUCED PRODUCE"
# 160  NaN   NaN      NaN                       unknown: "REDUCED PRODUCE"
# 161  NaN   NaN      NaN                       unknown: "REDUCED PRODUCE"
# 179  NaN   NaN      NaN                               unknown: "DELI MI"
# 180  NaN   NaN      NaN                               unknown: "DELI MI"
# 186  NaN   NaN      NaN                       unknown: "REDUCED PRODUCE"
# 432  NaN   NaN      NaN                          unknown: "ST ANTPLQ WH"
# 446  NaN   NaN      NaN        Duplicate of 5-5; unknown: "ST ANTPLQ WH"
# 467  NaN   NaN      NaN  Duplicate of 5-5 & 5-6; unknown: "ST ANTPLQ WH"

# %% [markdown]
# Item descriptions are too vague to be useful and are dropped.

# %%
unknown_count = df.Unknown.notna().sum()
print(f'{unknown_count} unknown items.')
df = df[df.Unknown.isna()]
df = df.drop(columns='Unknown')
# Out:
# 26 unknown items.

# %% [markdown]
# ### Quantity Column
# An integer representing multiple purchases of the same item

# %%
df.Quantity.value_counts(dropna=False)
# Out:
# NaN    1323
# 2.0     136
# 3.0      24
# 4.0       7
# 5.0       5
# 6.0       3
# Name: Quantity, dtype: int64

# %% [markdown]
# The Quantity column data is sparse. To make future analysis easier, rows will be repeated according to their Quantity value. Each row will now represent a single item. Notice that this will expand the size of the data set.

# %%
print(f'{df.Quantity.fillna(1).sum() - df.shape[0]} rows added from expanding Quantity data.')
df = df.loc[df.index.repeat(df.Quantity.fillna(1))]
df = df.drop(columns='Quantity')
# Out:
# 240.0 rows added from expanding Quantity data.

# %% [markdown]
# ### Hit Column & Miss Column
# Contains little to no data at this time and is dropped.

# %%
df = df.drop(columns=['Hit', 'Miss'])

# %% [markdown]
# ### Category Column
# Labels grocery by type.

# %%
df.Category = df.Category.astype('string')
df.Category.value_counts(dropna=False).head()
# Out:
# Fruit        241
# Vegetable    202
# Drink        159
# Meat         133
# Dairy        128
# Name: Category, dtype: Int64

# %% [markdown]
# ### Comment Column
# Contains miscellaneous notes from transcriber.

# %%
df.Comment.value_counts(dropna=False).head(10)
# Out:
# NaN                                         1352
# Duplicate of 1-1                              49
# category suggestion: "Petproduct"             44
# category suggestion: "Cleaningproduct"        22
# category suggestion: "Toiletries"             19
# Duplicate of 6-1                              17
# Duplicate of 1-2                              16
# Duplicate of 1-5                              15
# Duplicate of 3-1                              15
# category suggestion: "Householdgoods" ??      14
# Name: Comment, dtype: int64

# %%
duplicate_mask = df.Comment.str.contains(r'duplicate|repeat', case=False, na=False)
duplicate_drop_count = sum(duplicate_mask)
df = df[~duplicate_mask]
df.Comment = df.Comment.astype('string')
print(f'{duplicate_drop_count} duplicate rows.')
# Out:
# 201 duplicate rows.

# %% [markdown]
# ### A Cleaned Data Set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1537 entries, 0 to 2137
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        1537 non-null   uint8
#  1   Session   1537 non-null   uint8
#  2   Receipt   1537 non-null   uint8
#  3   Date      1221 non-null   datetime64[ns]
#  4   Item      1537 non-null   object
#  5   Category  1532 non-null   string
#  6   Comment   185 non-null    string
# dtypes: datetime64[ns](1), object(1), string(2), uint8(3)
# memory usage: 64.5+ KB

# %%
total_drop = null_receipt_count + null_item_count + unknown_count + duplicate_drop_count
print(f'Total row reduction: {total_drop} ({total_drop / initial_row_count:.0%})')
# Out:
# Total row reduction: 862 (40%)

# %%
df = df.reset_index(drop=True)
df.to_csv(f'{DATA_PATH}clean_{SHEET.lower()}.csv')
