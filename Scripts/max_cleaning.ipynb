# %%
import pandas as pd

# %%
df = pd.read_excel('../Data/Max, Samantha, Maria data.xlsx', sheet_name = 'Max')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2159 entries, 0 to 2158
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2159 non-null   float64
#  1   TP-Date          2159 non-null   float64
#  2   RecNum           1555 non-null   float64
#  3   RecDate          1718 non-null   datetime64[ns]
#  4   Item (Modifier)  2159 non-null   object
#  5   Secondary Name   38 non-null     object
#  6   Uncertain        37 non-null     object
#  7   Unknown          87 non-null     object
#  8   NumPurchased     274 non-null    float64
#  9   Hit              0 non-null      float64
#  10  Miss             0 non-null      float64
#  11  FoodCategory     2059 non-null   object
#  12  Comments         494 non-null    object
# dtypes: datetime64[ns](1), float64(6), object(6)
# memory usage: 219.4+ KB

# %%
df.ID = df.ID.astype('int32')

# %%
df[df.RecNum.isna()].head(50)
# Out:
#      ID  TP-Date  RecNum    RecDate             Item (modifier)  \
# 0   121      1.0     NaN 2020-06-05                 Salad (Blt)
# 1   121      1.0     NaN 2020-06-05                       Bacon
# 2   121      1.0     NaN 2020-06-05              Cookie (Sugar)
# 3   121      1.0     NaN 2020-06-05              Cake (Coconut)
# 4   121      1.0     NaN 2020-06-05                    Vitamins
# 5   121      1.0     NaN 2020-06-05             Chips (Cheetos)
# 6   121      1.0     NaN 2020-06-20                       Bread
# 7   121      1.0     NaN 2020-06-20              Bread (Garlic)
# 8   121      1.0     NaN 2020-06-20        Cereal (Raisin Bran)
# 9   121      1.0     NaN 2020-06-20                  Pain Cream
# 10  121      1.0     NaN 2020-06-20            Potpie (Chicken)
# 11  121      1.0     NaN 2020-06-20  Cheese Sticks (Mozzarella)
# 12  121      1.0     NaN 2020-06-20                      Shrimp
# 13  121      1.0     NaN 2020-06-20               Ramen Noodles
# ...
